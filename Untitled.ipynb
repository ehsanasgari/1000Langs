# %%
from utility.file_utility import FileUtility

# %%
files=list(set([l.split()[2] for l in FileUtility.load_list('log.txt')]))
files.sort()

# %%
import re
re.findall(r'\d\d\d\d\d\d\d\d', 'hello 42222222b3 I\'m a 32 string 230')
# Out:
# ['42222222']

# %%
[re.findall(r'\d\d\d\d\d\d\d\d',x.replace('_','')) for x in files]
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['70101307'],
#  ['70103522'],
#  ['74000106'],
#  ['74000106'],
#  ['74100606'],
#  ['74100606'],
#  ['74200943'],
#  ['74200943'],
#  ['74200943'],
#  ['74300503'],
#  ['74300503'],
#  ['74301236'],
#  ['74301236'],
#  ['74301604'],
#  ['74301604'],
#  ['74301838'],
#  ['74301838'],
#  ['74301916'],
#  ['74301916'],
#  ['74500911'],
#  ['74600309'],
#  ['74601231'],
#  ['74601231'],
#  ['74601433'],
#  ['74601544'],
#  ['74900115'],
#  ['01101001'],
#  ['01101002'],
#  ['01101003'],
#  ['01101004'],
#  ['01101005'],
#  ['01101006'],
#  ['01101007'],
#  ['01101008'],
#  ['01101009'],
#  ['01101010'],
#  ['01101011'],
#  ['01101012'],
#  ['01101013'],
#  ['01101014'],
#  ['01101015'],
#  ['01101016'],
#  ['01101017'],
#  ['01101018'],
#  ['01101019'],
#  ['01101020'],
#  ['01101021'],
#  ['01101022'],
#  ['01101023'],
#  ['01101024'],
#  ['01101025'],
#  ['01101026'],
#  ['01101027'],
#  ['01101028'],
# ...
